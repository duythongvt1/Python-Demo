# %%
# !pip install scikit-learn >= 0.23 --user

# %%
# !pip install underthesea --user
# Out:
# Requirement already satisfied: underthesea in c:\users\duyth\appdata\roaming\python\python37\site-packages (1.1.17)
# Requirement already satisfied: Click>=6.0 in c:\program files\anaconda\lib\site-packages (from underthesea) (7.0)
# Requirement already satisfied: languageflow==1.1.13a1 in c:\users\duyth\appdata\roaming\python\python37\site-packages (from underthesea) (1.1.13a1)
# Requirement already satisfied: nltk<3.5,>=3.4 in c:\program files\anaconda\lib\site-packages (from underthesea) (3.4.4)
# Requirement already satisfied: python-crfsuite==0.9.6 in c:\users\duyth\appdata\roaming\python\python37\site-packages (from underthesea) (0.9.6)
# Requirement already satisfied: joblib==0.13.2 in c:\program files\anaconda\lib\site-packages (from languageflow==1.1.13a1->underthesea) (0.13.2)
# Requirement already satisfied: requests in c:\program files\anaconda\lib\site-packages (from languageflow==1.1.13a1->underthesea) (2.22.0)
# Requirement already satisfied: tqdm in c:\program files\anaconda\lib\site-packages (from languageflow==1.1.13a1->underthesea) (4.32.1)
# Requirement already satisfied: tabulate in c:\users\duyth\appdata\roaming\python\python37\site-packages (from languageflow==1.1.13a1->underthesea) (0.8.7)
# Requirement already satisfied: clint in c:\users\duyth\appdata\roaming\python\python37\site-packages (from languageflow==1.1.13a1->underthesea) (0.5.1)
# Requirement already satisfied: scikit-learn==0.20.3 in c:\users\duyth\appdata\roaming\python\python37\site-packages (from languageflow==1.1.13a1->underthesea) (0.20.3)
# Requirement already satisfied: six in c:\users\duyth\appdata\roaming\python\python37\site-packages (from nltk<3.5,>=3.4->underthesea) (1.14.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\program files\anaconda\lib\site-packages (from requests->languageflow==1.1.13a1->underthesea) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\program files\anaconda\lib\site-packages (from requests->languageflow==1.1.13a1->underthesea) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\anaconda\lib\site-packages (from requests->languageflow==1.1.13a1->underthesea) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\program files\anaconda\lib\site-packages (from requests->languageflow==1.1.13a1->underthesea) (3.0.4)
# Requirement already satisfied: args in c:\users\duyth\appdata\roaming\python\python37\site-packages (from clint->languageflow==1.1.13a1->underthesea) (0.1.0)
# Requirement already satisfied: scipy>=0.13.3 in c:\program files\anaconda\lib\site-packages (from scikit-learn==0.20.3->languageflow==1.1.13a1->underthesea) (1.2.1)
# Requirement already satisfied: numpy>=1.8.2 in c:\program files\anaconda\lib\site-packages (from scikit-learn==0.20.3->languageflow==1.1.13a1->underthesea) (1.16.4)

# %%
a = """

Hà NộiNhận tập đề thi dày như quyển sách từ tay ‘giám thị’, Phạm Đăng Khoa cảm thấy nóng bừng khuôn mặt vì choáng ngợp.

Các "giám thị" ra hiệu lệnh bóc đề. Trong phòng họp sức chứa 3.800 chỗ ngồi của Trung tâm hội nghị quốc gia sáng 20/6, hơn 2.000 cử nhân, kỹ sư đã và sắp tốt nghiệp đứng trước 85 phút quyết định tương lai.

Họ là những người từng được đào tạo qua những chuyên ngành kỹ thuật, công nghệ thông tin... tại các trường đại học. Vượt qua hàng nghìn hồ sơ ứng tuyển vòng sơ loại, vòng thi tư duy, toán học, logic Global Samsung Aptitute Test (GSAT) là thử thách tiếp theo với họ trên đường trở thành nhân lực chất lượng cao của Samsung Việt Nam.

#
# Phòng thi lắp điều hòa, nhưng cổ áo Khoa ướt vã mồ hôi. Nhớ lại Khoa mới thấm thía lời khuyên của những "tiền bối" trên các diễn đàn trao đổi kinh nghiệm về bài thi GSAT của tập đoàn: "Phải thật bình tĩnh".
#
# Sắp tốt nghiệp đại học, Đăng Khoa đề ra mục tiêu nơi thực tập phải là môi trường cho mình mở tầm mắt, cả về kiến thức chuyên môn và kỹ năng sống nên quyết định gửi hồ sơ đến Samsung Bắc Ninh.
#
# "Đợt ấy có khoảng hơn 300 bạn có cùng nguyện vọng và số lượng công ty nhận chỉ khoảng hơn 20". Khoa nghĩ về tỷ lệ chọi, hơi lo lắng. Bảy ngày sau, Khoa ngồi đối diện 5 cán bộ của tập đoàn, bắt đầu trả lời những câu hỏi của vòng phỏng vấn, về kiến thức chuyên ngành, nội dung đồ án tốt nghiệp đang thực hiện và hiểu biết nền tảng về công ty.
#
# Khoa nhận mình ít khi mất bình tĩnh, đặc biệt khi thi cử. "Nhưng ngồi trong phòng phỏng vấn, dưới áp lực của 5 người, bị chú ý đánh giá từng cử chỉ, lời nói, tôi thực sự rất run". Trong trường đại học suốt bốn năm, sinh viên Bách khoa được đào tạo qua nhiều môn kỹ năng mềm, nhưng lúc ấy, Khoa "gần như quên hết".
#
# Một tuần sau Khoa nhận được thông báo trúng tuyển cùng 20 sinh viên khác. Chàng trai háo hức khăn gói đồ đạc, chuẩn bị cho hai tháng đào tạo nâng cao ở SDV Bắc Ninh.
#
# Nhiều ứng viên đánh giá GSAT tương đương với kỳ thi đại học lần hai.
#
# Nhiều ứng viên đánh giá GSAT tương đương với "kỳ thi đại học lần hai". Ảnh: Samsung Newsroom
#
# Hai tháng thực tập là một cuộc chạy nước rút, mỗi tuần nhóm sinh viên sẽ học một môn mới và làm bài kiểm tra ngay sau khi kết thúc. 6h mỗi sáng, gác lại thói quen dậy muộn của những ngày sinh viên, nhóm thực tập sinh phải sẵn sàng lên xe đón từ khu ký túc xá tới nhà ăn tập thể. Buổi học kéo dài từ 8h đến 20h, lồng ghép cả những khóa học tiếng Hàn Quốc, kỹ năng thuyết trình, giao tiếp, tiếng Anh...
#
# Mỗi lớp chỉ có 10 sinh viên, họ nhớ tên nhau ngay trong buổi đầu tiên. Khoa nhớ về những gương mặt rất trẻ mướt mải mồ hôi trong giờ học. Họ trở về giường ngủ khi cả chân tay lẫn đầu óc đều mệt mỏi rã rời, nhưng chỉ cần nghĩ đến buổi học ngày mai, Khoa và bè bạn lại hứng khởi. Từ tuần đào tạo thứ ba, cậu đặt ra quyết tâm, mình sẽ phải làm việc ở nơi này, hoặc ít ra là môi trường tương tự.
#
# Trở về từ đợt đào tạo, Khoa chỉ còn cách cánh cổng SEV một tấm bằng đại học và bốn vòng thi tuyển. Toàn bộ tâm trí năm cuối, cậu đổ dồn cho đồ án tốt nghiệp và một bộ hồ sơ ứng tuyển. Nhưng dịch bệnh ập đến nằm ngoài dự liệu.
#
# Những người từng tham gia GSAT chỉ dặn Lan "chuẩn bị tâm lý" mà không có thêm một gợi ý nào khác về nội dung, đề thi hay cách làm bài. 85 phút trong phòng thi với 85 câu hỏi, không được sử dụng cả máy tính cầm tay, Lan không có bất kỳ sự hỗ trợ nào ngoài chiếc bút và "cái đầu phải nhảy số thật nhanh". Cô gái 22 tuổi một lần nữa vận dụng chiến lược làm bài thi đại học "câu nào chắc chắn đáp án làm trước, câu khó làm sau". Và "ngơ ngác, không biết mình vừa trải qua những gì", là cảm giác lúc bước ra khỏi phòng thi.
#
# Không giống bạn bè xung quanh, "rải hồ sơ như tiên nữ rải hoa" đi khắp nơi để tăng cơ hội, Lan bảo mình là người "bỏ trứng một giỏ". Tập đoàn này là nơi duy nhất cô nộp hồ sơ ứng tuyển vì muốn dành toàn bộ "trí lực" cho nơi làm việc mơ ước. Khác với những thanh niên bước qua kỳ năm 2011, lớp trẻ như Lan sau này có điều kiện tìm hiểu về doanh nghiệp kỹ càng hơn.
#
# Tháng 6 tốt nghiệp đại học, tháng 9 thi tuyển, tháng 12 bắt đầu làm việc chính thức trong phòng đối ngoại của SEVT- Samsung Việt Nam tại Thái Nguyên. Cuộc đời Lan trong mắt nhiều người là con đường thẳng và thuận lợi. Nhưng ngay cả với những người đang có công việc ổn định, dịch bệnh vẫn trở thành nguy cơ.
#
# Nếu nỗi lo của những sinh viên như Khoa là lỡ dịp tuyển dụng, thì của Nhật Lan là nỗi lo cắt giảm nhân sự, đặc biệt là với một nhân viên mới. Nhưng lời hứa "không để một ai mất việc" của lãnh đạo công ty đã được thực hiện, ít nhất đến lúc này.
#
# "Tôi biết có những người từng trượt rất nhiều lần vẫn quyết tâm quay lại thử sức", Phạm Đăng Khoa nói.
#
# Gia đình chàng trai trẻ ở Nam Định hồi hộp ngóng đợi vào kết quả cuộc thi của con trai. Mẹ Khoa nhận được điện thoại từ đêm trước báo con đi thi, lẳng lặng đi thắp nén hương cầu khấn gia tiên, như thói quen ngày xưa khi Khoa thi đại học.
#
# Phong Linh
#
#     Hơn 2.000 người thi vào Samsung Việt Nam 25

# %%
from underthesea import (sent_tokenize,word_tokenize,pos_tag,chunk)

# %%
sentences = underthesea.sent_tokenize(a)

# %%
sentences
# Out:
# ['\n\nHà NộiNhận tập đề thi dày như quyển sách từ tay ‘giám thị’, Phạm Đăng Khoa cảm thấy nóng bừng khuôn mặt vì choáng ngợp.',
#  'Các "giám thị" ra hiệu lệnh bóc đề.',
#  'Trong phòng họp sức chứa 3.800 chỗ ngồi của Trung tâm hội nghị quốc gia sáng 20/6, hơn 2.000 cử nhân, kỹ sư đã và sắp tốt nghiệp đứng trước 85 phút quyết định tương lai.',
#  'Họ là những người từng được đào tạo qua những chuyên ngành kỹ thuật, công nghệ thông tin... tại các trường đại học.',
#  'Vượt qua hàng nghìn hồ sơ ứng tuyển vòng sơ loại, vòng thi tư duy, toán học, logic Global Samsung Aptitute Test (GSAT) là thử thách tiếp theo với họ trên đường trở thành nhân lực chất lượng cao của Samsung Việt Nam.',
#  'Các ứng viên dự thi GSAT tại Trung tâm hội nghị quốc gia.',
#  'Các ứng viên dự thi GSAT tại Trung tâm hội nghị quốc gia.',
#  'Ảnh: Samsung Newsroom\n\nNhiều người đánh giá GSAT "khắc nghiệt hơn cả kỳ thi đại học của Việt Nam".',
#  'Đề thi GSAT của Samsung toàn cầu có cùng nội dung, được niêm phong từ tập đoàn chuyển tới các nước.',
#  'Đề thi gửi về Việt Nam sẽ được chuyển tới kho lưu trữ, giám sát bằng camera 24/24.',
#  'Thành viên ban tổ chức cuộc thi hay nhân viên tập đoàn chỉ nhìn thấy đề sau khi các thí sinh bắt đầu làm bài.',
#  'Hàng trăm nhân lực được huy động để chuẩn bị cho kỳ thi trong vòng hai tháng.',
#  'Kết thúc GSAT, toàn bộ bài thi được scan và chuyển về Hàn Quốc để chấm.',
#  'GSAT tổ chức mỗi năm hai kỳ vào tháng 3-4, thời điểm có thể đón đầu lứa sinh viên chuẩn bị tốt nghiệp và tháng 9-10, khi các cử nhân đã lấy bằng và chuẩn bị đi làm.',
#  'Kỳ GSAT đầu tiên diễn ra năm 2011, trở thành "bộ lọc" để tập đoàn này có được nguồn nhân lực chất lượng cao.',
#  'GSAT 2020 đánh dấu chặng đường mười năm với 190.000 hồ sơ dự tuyển, gần 60.000 người tham gia kỳ thi và 14.000 nhân viên được tuyển dụng.',
#  'Nhiều người trong số đó sau này đảm nhận các vị trí chủ chốt của Samsung Việt Nam.',
#  'Phạm Đăng Khoa đỗ vào ngành Điều khiển tự động hóa, Đại học Bách Khoa năm 2015 với 26,75 điểm khối A và đỗ cùng lúc ngành Y đa khoa của Đại học Quốc gia Hà Nội.',
#  'Kỳ thi đại học với chàng trai Nam Định ngày ấy như một "cuộc dạo chơi", nhưng lần này "GSAT thực sự là một cú sốc".',
#  '45 trang đề thi trước mặt, 85 câu hỏi, 85 phút, Khoa không có một giây để lãng phí.',
#  'Phòng thi lắp điều hòa, nhưng cổ áo Khoa ướt vã mồ hôi.',
#  'Nhớ lại Khoa mới thấm thía lời khuyên của những "tiền bối" trên các diễn đàn trao đổi kinh nghiệm về bài thi GSAT của tập đoàn: "Phải thật bình tĩnh".',
#  'Sắp tốt nghiệp đại học, Đăng Khoa đề ra mục tiêu nơi thực tập phải là môi trường cho mình mở tầm mắt, cả về kiến thức chuyên môn và kỹ năng sống nên quyết định gửi hồ sơ đến Samsung Bắc Ninh.',
#  '"Đợt ấy có khoảng hơn 300 bạn có cùng nguyện vọng và số lượng công ty nhận chỉ khoảng hơn 20".',
#  'Khoa nghĩ về tỷ lệ chọi, hơi lo lắng.',
#  'Bảy ngày sau, Khoa ngồi đối diện 5 cán bộ của tập đoàn, bắt đầu trả lời những câu hỏi của vòng phỏng vấn, về kiến thức chuyên ngành, nội dung đồ án tốt nghiệp đang thực hiện và hiểu biết nền tảng về công ty.',
#  'Khoa nhận mình ít khi mất bình tĩnh, đặc biệt khi thi cử.',
#  '"Nhưng ngồi trong phòng phỏng vấn, dưới áp lực của 5 người, bị chú ý đánh giá từng cử chỉ, lời nói, tôi thực sự rất run".',
#  'Trong trường đại học suốt bốn năm, sinh viên Bách khoa được đào tạo qua nhiều môn kỹ năng mềm, nhưng lúc ấy, Khoa "gần như quên hết".',
#  'Một tuần sau Khoa nhận được thông báo trúng tuyển cùng 20 sinh viên khác.',
#  'Chàng trai háo hức khăn gói đồ đạc, chuẩn bị cho hai tháng đào tạo nâng cao ở SDV Bắc Ninh.',
#  'Nhiều ứng viên đánh giá GSAT tương đương với kỳ thi đại học lần hai.',
#  'Nhiều ứng viên đánh giá GSAT tương đương với "kỳ thi đại học lần hai".',
#  'Ảnh: Samsung Newsroom\n\nHai tháng thực tập là một cuộc chạy nước rút, mỗi tuần nhóm sinh viên sẽ học một môn mới và làm bài kiểm tra ngay sau khi kết thúc.',
#  '6h mỗi sáng, gác lại thói quen dậy muộn của những ngày sinh viên, nhóm thực tập sinh phải sẵn sàng lên xe đón từ khu ký túc xá tới nhà ăn tập thể.',
#  'Buổi học kéo dài từ 8h đến 20h, lồng ghép cả những khóa học tiếng Hàn Quốc, kỹ năng thuyết trình, giao tiếp, tiếng Anh...\n\nMỗi lớp chỉ có 10 sinh viên, họ nhớ tên nhau ngay trong buổi đầu tiên.',
#  'Khoa nhớ về những gương mặt rất trẻ mướt mải mồ hôi trong giờ học.',
#  'Họ trở về giường ngủ khi cả chân tay lẫn đầu óc đều mệt mỏi rã rời, nhưng chỉ cần nghĩ đến buổi học ngày mai, Khoa và bè bạn lại hứng khởi.',
#  'Từ tuần đào tạo thứ ba, cậu đặt ra quyết tâm, mình sẽ phải làm việc ở nơi này, hoặc ít ra là môi trường tương tự.',
#  'Trở về từ đợt đào tạo, Khoa chỉ còn cách cánh cổng SEV một tấm bằng đại học và bốn vòng thi tuyển.',
#  'Toàn bộ tâm trí năm cuối, cậu đổ dồn cho đồ án tốt nghiệp và một bộ hồ sơ ứng tuyển.',
#  'Nhưng dịch bệnh ập đến nằm ngoài dự liệu.',
#  'Kỳ nghỉ Tết dài nhất lịch sử trôi đi với những ca dương tính tăng liên tục.',
#  'Tháng 4, Khoa vẫn chưa được quay lại trường, bản đồ án và những môn học còn dở dang ám ảnh tâm trí cậu sinh viên năm cuối.',
#  'Nhưng điều khiến Khoa buồn nhất, là không thấy thông tin tuyển dụng của Samsung cho vòng GSAT vào tháng 4 như mọi năm.',
#  'Trên các forum online, những người trẻ tuổi cùng chí hướng thi thoảng vào bình luận "Covid thế này Samsung không tuyển dụng, các thanh niên thất nghiệp hết lượt rồi".',
#  'Theo thống kê của Tổng liên đoàn lao động đến hết tháng 5, gần 7.000 doanh nghiệp trong nước bị ảnh hưởng bởi dịch và gần nửa triệu lao động khu vực chính thức bị ảnh hưởng trực tiếp đến thu nhập, nguồn sống.',
#  'Đọc thông tin trên báo, Khoa vẫn tự tin khối công nghệ - tự động hóa sẽ ít bị "nếm đòn" hơn so với các ngành dịch vụ khác.',
#  'Cùng lúc đó, cậu nhận được lời mời đi làm của hai công ty tư nhân với chế độ đãi ngộ "chấp nhận được với những người mới ra trường".',
#  'Thanh niên trẻ đứng trước ngã ba đường: tiếp tục đợi chờ cuộc thi GSAT, hoặc lập tức thoát khỏi bức tranh ảm đạm của thị trường lao động mùa đại dịch.',
#  'Khoa dành một ngày để suy nghĩ và quyết định từ chối lời mời.',
#  '"Dù dịch bệnh, mình vẫn muốn dành cho bản thân một cơ hội tốt, chứ không phải nhắm mắt đưa chân".',
#  'Một giám thị kiểm tra tài liệu của ứng viên trước giờ làm bài.',
#  'Một "giám thị" kiểm tra tài liệu của ứng viên trước giờ làm bài.',
#  'Ảnh: Samsung Newsroom\n\nCuối cùng, GSAT 2020 vẫn diễn ra, dù trễ hơn thường niên hai tháng, trong bối cảnh Covid-19 đã được kiểm soát tốt tại Việt Nam.',
#  'Kỳ GSAT năm nay có thêm vòng kiểm tra thân nhiệt, phát khẩu trang, khử trùng và giãn cách nhằm hạn chế tối đa sự lây lan của dịch bệnh.',
#  '"Dù ảnh hưởng của dịch bệnh, Samsung Việt Nam vẫn tổ chức tuyển dụng trên quy mô lớn để chuẩn bị nguồn lực cho kế hoạch phát triển trong thời gian tới và chung tay giải quyết vấn đề thất nghiệp trong giới trẻ Việt Nam", đại diện Samsung cho biết.',
#  'Ông Jang Joon Hyuk, Tổng trưởng phòng nhân sự (SEVT) nói thêm "việc tuyển dụng trực tiếp quy mô như thế này trong thời điểm hiện tại chỉ có thể được tổ chức tại Việt Nam".',
#  '"Giống như lần thứ hai bước chân đi thi đại học vậy", Nhật Lan nhớ lại lần đầu bước chân vào Trung tâm hội nghị quốc gia Mỹ Đình, trong kỳ thi GSAT tháng 9/2019.',
#  'Dòng người trật tự, xếp hàng kéo dài từ cửa vào đến tận ngoài sân.',
#  'Nhiều người mang theo túi nhỏ để sẵn bút, giấy, tay xách theo chai nước.',
#  'Chuông báo vào phòng, các "giám thị" giơ tập đề lên để "thí sinh" nhìn rõ dấu niêm phong.',
#  'Không khí nhắc Nhật Lan nhớ về mùa hè sáu năm trước.',
#  'Nữ sinh quê Vĩnh Phúc khi ấy cũng phải vượt qua hàng nghìn "sĩ tử" để giành lấy một suất ghi danh vào Học viện Tài chính, chỉ có một điều khác kỳ thi này không có bố mẹ đi cùng.',
#  'Những người từng tham gia GSAT chỉ dặn Lan "chuẩn bị tâm lý" mà không có thêm một gợi ý nào khác về nội dung, đề thi hay cách làm bài.',
#  '85 phút trong phòng thi với 85 câu hỏi, không được sử dụng cả máy tính cầm tay, Lan không có bất kỳ sự hỗ trợ nào ngoài chiếc bút và "cái đầu phải nhảy số thật nhanh".',
#  'Cô gái 22 tuổi một lần nữa vận dụng chiến lược làm bài thi đại học "câu nào chắc chắn đáp án làm trước, câu khó làm sau".',
#  'Và "ngơ ngác, không biết mình vừa trải qua những gì", là cảm giác lúc bước ra khỏi phòng thi.',
#  'Không giống bạn bè xung quanh, "rải hồ sơ như tiên nữ rải hoa" đi khắp nơi để tăng cơ hội, Lan bảo mình là người "bỏ trứng một giỏ".',
#  'Tập đoàn này là nơi duy nhất cô nộp hồ sơ ứng tuyển vì muốn dành toàn bộ "trí lực" cho nơi làm việc mơ ước.',
#  'Khác với những thanh niên bước qua kỳ năm 2011, lớp trẻ như Lan sau này có điều kiện tìm hiểu về doanh nghiệp kỹ càng hơn.',
#  'Tháng 6 tốt nghiệp đại học, tháng 9 thi tuyển, tháng 12 bắt đầu làm việc chính thức trong phòng đối ngoại của SEVT- Samsung Việt Nam tại Thái Nguyên.',
#  'Cuộc đời Lan trong mắt nhiều người là con đường thẳng và thuận lợi.',
#  'Nhưng ngay cả với những người đang có công việc ổn định, dịch bệnh vẫn trở thành nguy cơ.',
#  'Nếu nỗi lo của những sinh viên như Khoa là lỡ dịp tuyển dụng, thì của Nhật Lan là nỗi lo cắt giảm nhân sự, đặc biệt là với một nhân viên mới.',
#  'Nhưng lời hứa "không để một ai mất việc" của lãnh đạo công ty đã được thực hiện, ít nhất đến lúc này.',
#  '"Tôi biết có những người từng trượt rất nhiều lần vẫn quyết tâm quay lại thử sức", Phạm Đăng Khoa nói.',
#  'Gia đình chàng trai trẻ ở Nam Định hồi hộp ngóng đợi vào kết quả cuộc thi của con trai.',
#  'Mẹ Khoa nhận được điện thoại từ đêm trước báo con đi thi, lẳng lặng đi thắp nén hương cầu khấn gia tiên, như thói quen ngày xưa khi Khoa thi đại học.',
#  'Phong Linh\n\n    Hơn 2.000 người thi vào Samsung Việt Nam 25']

# %%
sent_1 =  'Đề thi GSAT của Samsung toàn cầu có cùng nội dung, được niêm phong từ tập đoàn chuyển tới các nước.'
# S1 = "Đề thi GSAT của Samsung toàn cầu"
# V1 = "có"
# A+N1 = "cùng nội dung"

# V2 = "được niêm phong"
#

# %%
pos_tag(sent_1)
# Out:
# [('Đề', 'Np'),
#  ('thi', 'V'),
#  ('GSAT', 'Np'),
#  ('của', 'E'),
#  ('Samsung', 'Np'),
#  ('toàn cầu', 'N'),
#  ('có', 'V'),
#  ('cùng', 'A'),
#  ('nội dung', 'N'),
#  (',', 'CH'),
#  ('được', 'V'),
#  ('niêm phong', 'V'),
#  ('từ', 'E'),
#  ('tập đoàn', 'N'),
#  ('chuyển', 'V'),
#  ('tới', 'E'),
#  ('các', 'L'),
#  ('nước', 'N'),
#  ('.', 'CH')]

# %%
sent2 = chunk("Nhận tập đề thi dày như quyển sách từ tay giám thị Phạm Đăng Khoa cảm thấy nóng bừng khuôn mặt vì choáng ngợp.")
sent2
# Out:
# [('Nhận', 'V', 'B-VP'),
#  ('tập', 'V', 'B-VP'),
#  ('đề', 'N', 'B-NP'),
#  ('thi', 'V', 'B-VP'),
#  ('dày', 'A', 'B-AP'),
#  ('như', 'C', 'O'),
#  ('quyển', 'Nc', 'B-NP'),
#  ('sách', 'N', 'B-NP'),
#  ('từ', 'E', 'B-PP'),
#  ('tay', 'N', 'B-NP'),
#  ('giám thị Phạm', 'N', 'B-NP'),
#  ('Đăng Khoa', 'Np', 'B-NP'),
#  ('cảm thấy', 'V', 'B-VP'),
#  ('nóng bừng', 'N', 'B-NP'),
#  ('khuôn mặt', 'N', 'B-NP'),
#  ('vì', 'E', 'B-PP'),
#  ('choáng ngợp', 'V', 'B-VP'),
#  ('.', 'CH', 'O')]

# %%
N = [sent2[i][2] for i in range(len(sent2))]
N
# Out:
# ['B-VP',
#  'B-VP',
#  'B-NP',
#  'B-VP',
#  'B-AP',
#  'O',
#  'B-NP',
#  'B-NP',
#  'B-PP',
#  'B-NP',
#  'B-NP',
#  'B-VP',
#  'B-NP',
#  'O',
#  'B-NP',
#  'B-VP',
#  'B-NP',
#  'B-NP',
#  'B-PP',
#  'B-VP',
#  'O']

# %%
sent3 = chunk('GSAT tổ chức mỗi năm hai kỳ vào tháng 3-4, thời điểm có thể đón đầu lứa sinh viên chuẩn bị tốt nghiệp và tháng 9-10, khi các cử nhân đã lấy bằng và chuẩn bị đi làm.')
N = [sent3[i] for i in range(len(sent3))]
print(sent3)
N
# Out:
# [('GSAT', 'Np', 'B-NP'), ('tổ chức', 'V', 'B-VP'), ('mỗi', 'L', 'B-NP'), ('năm', 'N', 'B-NP'), ('hai', 'M', 'B-NP'), ('kỳ', 'N', 'B-NP'), ('vào', 'E', 'B-PP'), ('tháng', 'N', 'B-NP'), ('3-4', 'M', 'B-NP'), (',', 'CH', 'O'), ('thời điểm', 'N', 'B-NP'), ('có thể', 'R', 'O'), ('đón đầu', 'V', 'B-VP'), ('lứa', 'N', 'B-NP'), ('sinh viên', 'N', 'B-NP'), ('chuẩn bị', 'V', 'B-VP'), ('tốt nghiệp', 'V', 'B-VP'), ('và', 'C', 'O'), ('tháng', 'N', 'B-NP'), ('9-10', 'M', 'B-NP'), (',', 'CH', 'O'), ('khi', 'N', 'B-NP'), ('các', 'L', 'B-NP'), ('cử nhân', 'N', 'B-NP'), ('đã', 'R', 'O'), ('lấy', 'V', 'B-VP'), ('bằng', 'N', 'B-NP'), ('và', 'C', 'O'), ('chuẩn bị', 'V', 'B-VP'), ('đi', 'V', 'B-VP'), ('làm', 'V', 'B-VP'), ('.', 'CH', 'O')]
# [('GSAT', 'Np', 'B-NP'),
#  ('tổ chức', 'V', 'B-VP'),
#  ('mỗi', 'L', 'B-NP'),
#  ('năm', 'N', 'B-NP'),
#  ('hai', 'M', 'B-NP'),
#  ('kỳ', 'N', 'B-NP'),
#  ('vào', 'E', 'B-PP'),
#  ('tháng', 'N', 'B-NP'),
#  ('3-4', 'M', 'B-NP'),
#  (',', 'CH', 'O'),
#  ('thời điểm', 'N', 'B-NP'),
#  ('có thể', 'R', 'O'),
#  ('đón đầu', 'V', 'B-VP'),
#  ('lứa', 'N', 'B-NP'),
#  ('sinh viên', 'N', 'B-NP'),
#  ('chuẩn bị', 'V', 'B-VP'),
#  ('tốt nghiệp', 'V', 'B-VP'),
#  ('và', 'C', 'O'),
#  ('tháng', 'N', 'B-NP'),
#  ('9-10', 'M', 'B-NP'),
#  (',', 'CH', 'O'),
#  ('khi', 'N', 'B-NP'),
#  ('các', 'L', 'B-NP'),
#  ('cử nhân', 'N', 'B-NP'),
#  ('đã', 'R', 'O'),
#  ('lấy', 'V', 'B-VP'),
#  ('bằng', 'N', 'B-NP'),
#  ('và', 'C', 'O'),
#  ('chuẩn bị', 'V', 'B-VP'),
#  ('đi', 'V', 'B-VP'),
#  ('làm', 'V', 'B-VP'),
#  ('.', 'CH', 'O')]

# %%
from random import randint

# %%
sent = sentences[randint(0,len(sentences))]
sent
# Out:
# 'Kết thúc GSAT, toàn bộ bài thi được scan và chuyển về Hàn Quốc để chấm.'

# %%
sent_chunk = chunk(sent)
sent_chunk
# Out:
# [('Kết thúc', 'V', 'B-VP'),
#  ('GSAT', 'Np', 'B-NP'),
#  (',', 'CH', 'O'),
#  ('toàn bộ', 'L', 'B-NP'),
#  ('bài', 'N', 'B-NP'),
#  ('thi', 'V', 'B-VP'),
#  ('được', 'V', 'B-VP'),
#  ('scan', 'V', 'B-VP'),
#  ('và', 'C', 'O'),
#  ('chuyển', 'V', 'B-VP'),
#  ('về', 'E', 'B-PP'),
#  ('Hàn Quốc', 'Np', 'B-NP'),
#  ('để', 'E', 'B-PP'),
#  ('chấm', 'V', 'B-VP'),
#  ('.', 'CH', 'O')]

# %%
sent = sentences[randint(0,len(sentences))]
sent
# Out:
# 'Thành viên ban tổ chức cuộc thi hay nhân viên tập đoàn chỉ nhìn thấy đề sau khi các thí sinh bắt đầu làm bài.'

# %%
sent_chunk = chunk(sent)
sent_chunk
# Out:
# [('Thành viên', 'N', 'B-NP'),
#  ('ban', 'N', 'B-NP'),
#  ('tổ chức', 'V', 'B-VP'),
#  ('cuộc', 'N', 'B-NP'),
#  ('thi', 'V', 'B-VP'),
#  ('hay', 'C', 'O'),
#  ('nhân viên', 'N', 'B-NP'),
#  ('tập đoàn', 'N', 'B-NP'),
#  ('chỉ', 'R', 'O'),
#  ('nhìn', 'V', 'B-VP'),
#  ('thấy', 'V', 'B-VP'),
#  ('đề', 'N', 'B-NP'),
#  ('sau', 'N', 'B-NP'),
#  ('khi', 'N', 'B-NP'),
#  ('các', 'L', 'B-NP'),
#  ('thí sinh', 'N', 'B-NP'),
#  ('bắt đầu', 'V', 'B-VP'),
#  ('làm', 'V', 'B-VP'),
#  ('bài', 'N', 'B-NP'),
#  ('.', 'CH', 'O')]

# %%
def hasComma(chunk):
    for token in chunk:
        if token[0]==",": return True
    return False

hasComma(sent)
# Out:
# False

# %%
no_comma = []
has_comma = []
for sent in sentences:
    if hasComma(sent):
        has_comma.append(sent)
    else:
        no_comma.append(sent)

# %%
no_comma
# Out:
# ['Các "giám thị" ra hiệu lệnh bóc đề.',
#  'Các ứng viên dự thi GSAT tại Trung tâm hội nghị quốc gia.',
#  'Các ứng viên dự thi GSAT tại Trung tâm hội nghị quốc gia.',
#  'Ảnh: Samsung Newsroom\n\nNhiều người đánh giá GSAT "khắc nghiệt hơn cả kỳ thi đại học của Việt Nam".',
#  'Thành viên ban tổ chức cuộc thi hay nhân viên tập đoàn chỉ nhìn thấy đề sau khi các thí sinh bắt đầu làm bài.',
#  'Hàng trăm nhân lực được huy động để chuẩn bị cho kỳ thi trong vòng hai tháng.',
#  'Nhiều người trong số đó sau này đảm nhận các vị trí chủ chốt của Samsung Việt Nam.',
#  'Nhớ lại Khoa mới thấm thía lời khuyên của những "tiền bối" trên các diễn đàn trao đổi kinh nghiệm về bài thi GSAT của tập đoàn: "Phải thật bình tĩnh".',
#  '"Đợt ấy có khoảng hơn 300 bạn có cùng nguyện vọng và số lượng công ty nhận chỉ khoảng hơn 20".',
#  'Một tuần sau Khoa nhận được thông báo trúng tuyển cùng 20 sinh viên khác.',
#  'Nhiều ứng viên đánh giá GSAT tương đương với kỳ thi đại học lần hai.',
#  'Nhiều ứng viên đánh giá GSAT tương đương với "kỳ thi đại học lần hai".',
#  'Khoa nhớ về những gương mặt rất trẻ mướt mải mồ hôi trong giờ học.',
#  'Nhưng dịch bệnh ập đến nằm ngoài dự liệu.',
#  'Kỳ nghỉ Tết dài nhất lịch sử trôi đi với những ca dương tính tăng liên tục.',
#  'Khoa dành một ngày để suy nghĩ và quyết định từ chối lời mời.',
#  'Một giám thị kiểm tra tài liệu của ứng viên trước giờ làm bài.',
#  'Một "giám thị" kiểm tra tài liệu của ứng viên trước giờ làm bài.',
#  'Không khí nhắc Nhật Lan nhớ về mùa hè sáu năm trước.',
#  'Tập đoàn này là nơi duy nhất cô nộp hồ sơ ứng tuyển vì muốn dành toàn bộ "trí lực" cho nơi làm việc mơ ước.',
#  'Cuộc đời Lan trong mắt nhiều người là con đường thẳng và thuận lợi.',
#  'Gia đình chàng trai trẻ ở Nam Định hồi hộp ngóng đợi vào kết quả cuộc thi của con trai.',
#  'Phong Linh\n\n    Hơn 2.000 người thi vào Samsung Việt Nam 25']

# %%
has_comma
# Out:
# ['\n\nHà NộiNhận tập đề thi dày như quyển sách từ tay ‘giám thị’, Phạm Đăng Khoa cảm thấy nóng bừng khuôn mặt vì choáng ngợp.',
#  'Trong phòng họp sức chứa 3.800 chỗ ngồi của Trung tâm hội nghị quốc gia sáng 20/6, hơn 2.000 cử nhân, kỹ sư đã và sắp tốt nghiệp đứng trước 85 phút quyết định tương lai.',
#  'Họ là những người từng được đào tạo qua những chuyên ngành kỹ thuật, công nghệ thông tin... tại các trường đại học.',
#  'Vượt qua hàng nghìn hồ sơ ứng tuyển vòng sơ loại, vòng thi tư duy, toán học, logic Global Samsung Aptitute Test (GSAT) là thử thách tiếp theo với họ trên đường trở thành nhân lực chất lượng cao của Samsung Việt Nam.',
#  'Đề thi GSAT của Samsung toàn cầu có cùng nội dung, được niêm phong từ tập đoàn chuyển tới các nước.',
#  'Đề thi gửi về Việt Nam sẽ được chuyển tới kho lưu trữ, giám sát bằng camera 24/24.',
#  'Kết thúc GSAT, toàn bộ bài thi được scan và chuyển về Hàn Quốc để chấm.',
#  'GSAT tổ chức mỗi năm hai kỳ vào tháng 3-4, thời điểm có thể đón đầu lứa sinh viên chuẩn bị tốt nghiệp và tháng 9-10, khi các cử nhân đã lấy bằng và chuẩn bị đi làm.',
#  'Kỳ GSAT đầu tiên diễn ra năm 2011, trở thành "bộ lọc" để tập đoàn này có được nguồn nhân lực chất lượng cao.',
#  'GSAT 2020 đánh dấu chặng đường mười năm với 190.000 hồ sơ dự tuyển, gần 60.000 người tham gia kỳ thi và 14.000 nhân viên được tuyển dụng.',
#  'Phạm Đăng Khoa đỗ vào ngành Điều khiển tự động hóa, Đại học Bách Khoa năm 2015 với 26,75 điểm khối A và đỗ cùng lúc ngành Y đa khoa của Đại học Quốc gia Hà Nội.',
#  'Kỳ thi đại học với chàng trai Nam Định ngày ấy như một "cuộc dạo chơi", nhưng lần này "GSAT thực sự là một cú sốc".',
#  '45 trang đề thi trước mặt, 85 câu hỏi, 85 phút, Khoa không có một giây để lãng phí.',
#  'Phòng thi lắp điều hòa, nhưng cổ áo Khoa ướt vã mồ hôi.',
#  'Sắp tốt nghiệp đại học, Đăng Khoa đề ra mục tiêu nơi thực tập phải là môi trường cho mình mở tầm mắt, cả về kiến thức chuyên môn và kỹ năng sống nên quyết định gửi hồ sơ đến Samsung Bắc Ninh.',
#  'Khoa nghĩ về tỷ lệ chọi, hơi lo lắng.',
#  'Bảy ngày sau, Khoa ngồi đối diện 5 cán bộ của tập đoàn, bắt đầu trả lời những câu hỏi của vòng phỏng vấn, về kiến thức chuyên ngành, nội dung đồ án tốt nghiệp đang thực hiện và hiểu biết nền tảng về công ty.',
#  'Khoa nhận mình ít khi mất bình tĩnh, đặc biệt khi thi cử.',
#  '"Nhưng ngồi trong phòng phỏng vấn, dưới áp lực của 5 người, bị chú ý đánh giá từng cử chỉ, lời nói, tôi thực sự rất run".',
#  'Trong trường đại học suốt bốn năm, sinh viên Bách khoa được đào tạo qua nhiều môn kỹ năng mềm, nhưng lúc ấy, Khoa "gần như quên hết".',
#  'Chàng trai háo hức khăn gói đồ đạc, chuẩn bị cho hai tháng đào tạo nâng cao ở SDV Bắc Ninh.',
#  'Ảnh: Samsung Newsroom\n\nHai tháng thực tập là một cuộc chạy nước rút, mỗi tuần nhóm sinh viên sẽ học một môn mới và làm bài kiểm tra ngay sau khi kết thúc.',
#  '6h mỗi sáng, gác lại thói quen dậy muộn của những ngày sinh viên, nhóm thực tập sinh phải sẵn sàng lên xe đón từ khu ký túc xá tới nhà ăn tập thể.',
#  'Buổi học kéo dài từ 8h đến 20h, lồng ghép cả những khóa học tiếng Hàn Quốc, kỹ năng thuyết trình, giao tiếp, tiếng Anh...\n\nMỗi lớp chỉ có 10 sinh viên, họ nhớ tên nhau ngay trong buổi đầu tiên.',
#  'Họ trở về giường ngủ khi cả chân tay lẫn đầu óc đều mệt mỏi rã rời, nhưng chỉ cần nghĩ đến buổi học ngày mai, Khoa và bè bạn lại hứng khởi.',
#  'Từ tuần đào tạo thứ ba, cậu đặt ra quyết tâm, mình sẽ phải làm việc ở nơi này, hoặc ít ra là môi trường tương tự.',
#  'Trở về từ đợt đào tạo, Khoa chỉ còn cách cánh cổng SEV một tấm bằng đại học và bốn vòng thi tuyển.',
#  'Toàn bộ tâm trí năm cuối, cậu đổ dồn cho đồ án tốt nghiệp và một bộ hồ sơ ứng tuyển.',
#  'Tháng 4, Khoa vẫn chưa được quay lại trường, bản đồ án và những môn học còn dở dang ám ảnh tâm trí cậu sinh viên năm cuối.',
#  'Nhưng điều khiến Khoa buồn nhất, là không thấy thông tin tuyển dụng của Samsung cho vòng GSAT vào tháng 4 như mọi năm.',
#  'Trên các forum online, những người trẻ tuổi cùng chí hướng thi thoảng vào bình luận "Covid thế này Samsung không tuyển dụng, các thanh niên thất nghiệp hết lượt rồi".',
#  'Theo thống kê của Tổng liên đoàn lao động đến hết tháng 5, gần 7.000 doanh nghiệp trong nước bị ảnh hưởng bởi dịch và gần nửa triệu lao động khu vực chính thức bị ảnh hưởng trực tiếp đến thu nhập, nguồn sống.',
#  'Đọc thông tin trên báo, Khoa vẫn tự tin khối công nghệ - tự động hóa sẽ ít bị "nếm đòn" hơn so với các ngành dịch vụ khác.',
#  'Cùng lúc đó, cậu nhận được lời mời đi làm của hai công ty tư nhân với chế độ đãi ngộ "chấp nhận được với những người mới ra trường".',
#  'Thanh niên trẻ đứng trước ngã ba đường: tiếp tục đợi chờ cuộc thi GSAT, hoặc lập tức thoát khỏi bức tranh ảm đạm của thị trường lao động mùa đại dịch.',
#  '"Dù dịch bệnh, mình vẫn muốn dành cho bản thân một cơ hội tốt, chứ không phải nhắm mắt đưa chân".',
#  'Ảnh: Samsung Newsroom\n\nCuối cùng, GSAT 2020 vẫn diễn ra, dù trễ hơn thường niên hai tháng, trong bối cảnh Covid-19 đã được kiểm soát tốt tại Việt Nam.',
#  'Kỳ GSAT năm nay có thêm vòng kiểm tra thân nhiệt, phát khẩu trang, khử trùng và giãn cách nhằm hạn chế tối đa sự lây lan của dịch bệnh.',
#  '"Dù ảnh hưởng của dịch bệnh, Samsung Việt Nam vẫn tổ chức tuyển dụng trên quy mô lớn để chuẩn bị nguồn lực cho kế hoạch phát triển trong thời gian tới và chung tay giải quyết vấn đề thất nghiệp trong giới trẻ Việt Nam", đại diện Samsung cho biết.',
#  'Ông Jang Joon Hyuk, Tổng trưởng phòng nhân sự (SEVT) nói thêm "việc tuyển dụng trực tiếp quy mô như thế này trong thời điểm hiện tại chỉ có thể được tổ chức tại Việt Nam".',
#  '"Giống như lần thứ hai bước chân đi thi đại học vậy", Nhật Lan nhớ lại lần đầu bước chân vào Trung tâm hội nghị quốc gia Mỹ Đình, trong kỳ thi GSAT tháng 9/2019.',
#  'Dòng người trật tự, xếp hàng kéo dài từ cửa vào đến tận ngoài sân.',
#  'Nhiều người mang theo túi nhỏ để sẵn bút, giấy, tay xách theo chai nước.',
#  'Chuông báo vào phòng, các "giám thị" giơ tập đề lên để "thí sinh" nhìn rõ dấu niêm phong.',
#  'Nữ sinh quê Vĩnh Phúc khi ấy cũng phải vượt qua hàng nghìn "sĩ tử" để giành lấy một suất ghi danh vào Học viện Tài chính, chỉ có một điều khác kỳ thi này không có bố mẹ đi cùng.',
#  'Những người từng tham gia GSAT chỉ dặn Lan "chuẩn bị tâm lý" mà không có thêm một gợi ý nào khác về nội dung, đề thi hay cách làm bài.',
#  '85 phút trong phòng thi với 85 câu hỏi, không được sử dụng cả máy tính cầm tay, Lan không có bất kỳ sự hỗ trợ nào ngoài chiếc bút và "cái đầu phải nhảy số thật nhanh".',
#  'Cô gái 22 tuổi một lần nữa vận dụng chiến lược làm bài thi đại học "câu nào chắc chắn đáp án làm trước, câu khó làm sau".',
#  'Và "ngơ ngác, không biết mình vừa trải qua những gì", là cảm giác lúc bước ra khỏi phòng thi.',
#  'Không giống bạn bè xung quanh, "rải hồ sơ như tiên nữ rải hoa" đi khắp nơi để tăng cơ hội, Lan bảo mình là người "bỏ trứng một giỏ".',
#  'Khác với những thanh niên bước qua kỳ năm 2011, lớp trẻ như Lan sau này có điều kiện tìm hiểu về doanh nghiệp kỹ càng hơn.',
#  'Tháng 6 tốt nghiệp đại học, tháng 9 thi tuyển, tháng 12 bắt đầu làm việc chính thức trong phòng đối ngoại của SEVT- Samsung Việt Nam tại Thái Nguyên.',
#  'Nhưng ngay cả với những người đang có công việc ổn định, dịch bệnh vẫn trở thành nguy cơ.',
#  'Nếu nỗi lo của những sinh viên như Khoa là lỡ dịp tuyển dụng, thì của Nhật Lan là nỗi lo cắt giảm nhân sự, đặc biệt là với một nhân viên mới.',
#  'Nhưng lời hứa "không để một ai mất việc" của lãnh đạo công ty đã được thực hiện, ít nhất đến lúc này.',
#  '"Tôi biết có những người từng trượt rất nhiều lần vẫn quyết tâm quay lại thử sức", Phạm Đăng Khoa nói.',
#  'Mẹ Khoa nhận được điện thoại từ đêm trước báo con đi thi, lẳng lặng đi thắp nén hương cầu khấn gia tiên, như thói quen ngày xưa khi Khoa thi đại học.']

# %%
list1 = [[chunk(sent)[i][1] for i in range(len(chunk(sent)))] for sent in no_comma]
# Out:
# [['L', 'CH', 'V', 'CH', 'V', 'N', 'V', 'N', 'CH'],
#  ['L', 'N', 'V', 'V', 'Np', 'E', 'N', 'N', 'N', 'CH'],
#  ['L', 'N', 'V', 'V', 'Np', 'E', 'N', 'N', 'N', 'CH'],
#  ['N',
#   'CH',
#   'Np',
#   'N',
#   'V',
#   'Np',
#   'CH',
#   'V',
#   'A',
#   'T',
#   'N',
#   'V',
#   'N',
#   'E',
#   'Np',
#   'CH',
#   'CH'],
#  ['N',
#   'N',
#   'V',
#   'N',
#   'V',
#   'C',
#   'N',
#   'N',
#   'R',
#   'V',
#   'V',
#   'N',
#   'N',
#   'N',
#   'L',
#   'N',
#   'V',
#   'V',
#   'N',
#   'CH'],
#  ['R', 'M', 'N', 'V', 'V', 'E', 'V', 'E', 'N', 'V', 'E', 'N', 'M', 'N', 'CH'],
#  ['A', 'Nc', 'E', 'N', 'P', 'N', 'V', 'L', 'N', 'A', 'E', 'Np', 'Np', 'CH'],
#  ['V',
#   'R',
#   'Np',
#   'R',
#   'V',
#   'N',
#   'V',
#   'E',
#   'L',
#   'CH',
#   'N',
#   'CH',
#   'E',
#   'L',
#   'N',
#   'V',
#   'N',
#   'E',
#   'N',
#   'V',
#   'Np',
#   'E',
#   'N',
#   'CH',
#   'CH',
#   'V',
#   'T',
#   'A',
#   'CH',
#   'CH'],
#  ['CH',
#   'N',
#   'P',
#   'V',
#   'A',
#   'A',
#   'M',
#   'N',
#   'V',
#   'A',
#   'N',
#   'C',
#   'N',
#   'N',
#   'V',
#   'R',
#   'A',
#   'A',
#   'M',
#   'CH',
#   'CH'],
#  ['M', 'N', 'N', 'Np', 'V', 'R', 'V', 'N', 'A', 'M', 'N', 'A', 'CH'],
#  ['A', 'N', 'V', 'Np', 'A', 'E', 'N', 'V', 'N', 'N', 'M', 'CH'],
#  ['A', 'N', 'V', 'Np', 'A', 'E', 'CH', 'N', 'V', 'N', 'N', 'M', 'CH', 'CH'],
#  ['Np', 'V', 'E', 'L', 'N', 'R', 'A', 'V', 'V', 'N', 'E', 'N', 'V', 'CH'],
#  ['C', 'N', 'V', 'R', 'V', 'E', 'N', 'CH'],
#  ['N', 'V', 'N', 'A', 'R', 'N', 'V', 'V', 'E', 'L', 'N', 'N', 'V', 'A', 'CH'],
#  ['Np', 'V', 'M', 'N', 'E', 'V', 'C', 'V', 'V', 'N', 'V', 'CH'],
#  ['M', 'N', 'V', 'N', 'E', 'N', 'E', 'N', 'V', 'N', 'CH'],
#  ['M', 'CH', 'N', 'CH', 'V', 'N', 'E', 'N', 'E', 'N', 'V', 'N', 'CH'],
#  ['N', 'V', 'Np', 'V', 'E', 'N', 'N', 'M', 'N', 'N', 'CH'],
#  ['N',
#   'P',
#   'V',
#   'N',
#   'A',
#   'Nc',
#   'V',
#   'N',
#   'V',
#   'E',
#   'V',
#   'V',
#   'L',
#   'CH',
#   'N',
#   'CH',
#   'E',
#   'N',
#   'V',
#   'V',
#   'CH'],
#  ['N', 'Np', 'E', 'N', 'A', 'Nc', 'V', 'N', 'V', 'C', 'A', 'CH'],
#  ['N', 'Nc', 'N', 'E', 'Np', 'V', 'V', 'E', 'N', 'N', 'V', 'E', 'N', 'CH'],
#  ['Np', 'Np', 'M', 'N', 'V', 'E', 'Np', 'Np', 'M']]

# %%
for item in list1:
    print(item)
# Out:
# ['L', 'CH', 'V', 'CH', 'V', 'N', 'V', 'N', 'CH']
# ['L', 'N', 'V', 'V', 'Np', 'E', 'N', 'N', 'N', 'CH']
# ['L', 'N', 'V', 'V', 'Np', 'E', 'N', 'N', 'N', 'CH']
# ['N', 'CH', 'Np', 'N', 'V', 'Np', 'CH', 'V', 'A', 'T', 'N', 'V', 'N', 'E', 'Np', 'CH', 'CH']
# ['N', 'N', 'V', 'N', 'V', 'C', 'N', 'N', 'R', 'V', 'V', 'N', 'N', 'N', 'L', 'N', 'V', 'V', 'N', 'CH']
# ['R', 'M', 'N', 'V', 'V', 'E', 'V', 'E', 'N', 'V', 'E', 'N', 'M', 'N', 'CH']
# ['A', 'Nc', 'E', 'N', 'P', 'N', 'V', 'L', 'N', 'A', 'E', 'Np', 'Np', 'CH']
# ['V', 'R', 'Np', 'R', 'V', 'N', 'V', 'E', 'L', 'CH', 'N', 'CH', 'E', 'L', 'N', 'V', 'N', 'E', 'N', 'V', 'Np', 'E', 'N', 'CH', 'CH', 'V', 'T', 'A', 'CH', 'CH']
# ['CH', 'N', 'P', 'V', 'A', 'A', 'M', 'N', 'V', 'A', 'N', 'C', 'N', 'N', 'V', 'R', 'A', 'A', 'M', 'CH', 'CH']
# ['M', 'N', 'N', 'Np', 'V', 'R', 'V', 'N', 'A', 'M', 'N', 'A', 'CH']
# ['A', 'N', 'V', 'Np', 'A', 'E', 'N', 'V', 'N', 'N', 'M', 'CH']
# ['A', 'N', 'V', 'Np', 'A', 'E', 'CH', 'N', 'V', 'N', 'N', 'M', 'CH', 'CH']
# ['Np', 'V', 'E', 'L', 'N', 'R', 'A', 'V', 'V', 'N', 'E', 'N', 'V', 'CH']
# ['C', 'N', 'V', 'R', 'V', 'E', 'N', 'CH']
# ['N', 'V', 'N', 'A', 'R', 'N', 'V', 'V', 'E', 'L', 'N', 'N', 'V', 'A', 'CH']
# ['Np', 'V', 'M', 'N', 'E', 'V', 'C', 'V', 'V', 'N', 'V', 'CH']
# ['M', 'N', 'V', 'N', 'E', 'N', 'E', 'N', 'V', 'N', 'CH']
# ['M', 'CH', 'N', 'CH', 'V', 'N', 'E', 'N', 'E', 'N', 'V', 'N', 'CH']
# ['N', 'V', 'Np', 'V', 'E', 'N', 'N', 'M', 'N', 'N', 'CH']
# ['N', 'P', 'V', 'N', 'A', 'Nc', 'V', 'N', 'V', 'E', 'V', 'V', 'L', 'CH', 'N', 'CH', 'E', 'N', 'V', 'V', 'CH']
# ['N', 'Np', 'E', 'N', 'A', 'Nc', 'V', 'N', 'V', 'C', 'A', 'CH']
# ['N', 'Nc', 'N', 'E', 'Np', 'V', 'V', 'E', 'N', 'N', 'V', 'E', 'N', 'CH']
# ['Np', 'Np', 'M', 'N', 'V', 'E', 'Np', 'Np', 'M']

# %%
import seaborn as sns
import pandas as pd
import itertools
import collections.Counter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-128-73b90932fc25> in <module>
#       2 import pandas as pd
#       3 import itertools
# ----> 4 import collections.Counter
#
# ModuleNotFoundError: No module named 'collections.Counter'

# %%
cols = list(set(itertools.chain.from_iterable(list1)))
cols
# Out:
# ['A', 'C', 'T', 'Np', 'CH', 'N', 'V', 'Nc', 'E', 'L', 'R', 'M', 'P']

# %%
from collections import Counter

# %%
c = Counter(list1[2])
c
# Out:
# Counter({'L': 1, 'N': 4, 'V': 2, 'Np': 1, 'E': 1, 'CH': 1})

# %%
df = pd.DataFrame(columns = cols)
df
# Out:
# Empty DataFrame
# Columns: [A, C, T, Np, CH, N, V, Nc, E, L, R, M, P]
# Index: []

# %%
for item in list1:
    df = df.append(pd.Series(Counter(item),dtype="int"),ignore_index = True)

df
# Out:
#       A    C    T   Np   CH     N    V   Nc    E    L    R    M    P
# 0   NaN  NaN  NaN  NaN  3.0   2.0  3.0  NaN  NaN  1.0  NaN  NaN  NaN
# 1   NaN  NaN  NaN  1.0  1.0   4.0  2.0  NaN  1.0  1.0  NaN  NaN  NaN
# 2   NaN  NaN  NaN  1.0  1.0   4.0  2.0  NaN  1.0  1.0  NaN  NaN  NaN
# 3   1.0  NaN  1.0  3.0  4.0   4.0  3.0  NaN  1.0  NaN  NaN  NaN  NaN
# 4   NaN  1.0  NaN  NaN  1.0  10.0  6.0  NaN  NaN  1.0  1.0  NaN  NaN
# 5   NaN  NaN  NaN  NaN  1.0   4.0  4.0  NaN  3.0  NaN  1.0  2.0  NaN
# 6   2.0  NaN  NaN  2.0  1.0   3.0  1.0  1.0  2.0  1.0  NaN  NaN  1.0
# 7   1.0  NaN  1.0  2.0  6.0   6.0  6.0  NaN  4.0  2.0  2.0  NaN  NaN
# 8   5.0  1.0  NaN  NaN  3.0   5.0  3.0  NaN  NaN  NaN  1.0  2.0  1.0
# 9   2.0  NaN  NaN  1.0  1.0   4.0  2.0  NaN  NaN  NaN  1.0  2.0  NaN
# 10  2.0  NaN  NaN  1.0  1.0   4.0  2.0  NaN  1.0  NaN  NaN  1.0  NaN
# 11  2.0  NaN  NaN  1.0  3.0   4.0  2.0  NaN  1.0  NaN  NaN  1.0  NaN
# 12  1.0  NaN  NaN  1.0  1.0   3.0  4.0  NaN  2.0  1.0  1.0  NaN  NaN
# 13  NaN  1.0  NaN  NaN  1.0   2.0  2.0  NaN  1.0  NaN  1.0  NaN  NaN
# 14  2.0  NaN  NaN  NaN  1.0   5.0  4.0  NaN  1.0  1.0  1.0  NaN  NaN
# 15  NaN  1.0  NaN  1.0  1.0   2.0  5.0  NaN  1.0  NaN  NaN  1.0  NaN
# 16  NaN  NaN  NaN  NaN  1.0   5.0  2.0  NaN  2.0  NaN  NaN  1.0  NaN
# 17  NaN  NaN  NaN  NaN  3.0   5.0  2.0  NaN  2.0  NaN  NaN  1.0  NaN
# 18  NaN  NaN  NaN  1.0  1.0   5.0  2.0  NaN  1.0  NaN  NaN  1.0  NaN
# 19  1.0  NaN  NaN  NaN  3.0   5.0  7.0  1.0  2.0  1.0  NaN  NaN  1.0
# 20  2.0  1.0  NaN  1.0  1.0   3.0  2.0  1.0  1.0  NaN  NaN  NaN  NaN
# 21  NaN  NaN  NaN  1.0  1.0   5.0  3.0  1.0  3.0  NaN  NaN  NaN  NaN
# 22  NaN  NaN  NaN  4.0  NaN   1.0  1.0  NaN  1.0  NaN  NaN  2.0  NaN

# %%
def make_df(string_list):
    list1 = [[chunk(sent)[i][1] for i in range(len(chunk(sent)))] for sent in no_comma]
    cols = list(set(itertools.chain.from_iterable(list1)))
    df = pd.DataFrame(columns = cols)
    for item in list1:
        df = df.append(pd.Series(Counter(item),dtype="int"),ignore_index = True)
    return df

# %%
df_hasComma = make_df(has_comma)

# %%
df_hasComma
# Out:
#       A    C    T   Np   CH     N    V   Nc    E    L    R    M    P
# 0   NaN  NaN  NaN  NaN  3.0   2.0  3.0  NaN  NaN  1.0  NaN  NaN  NaN
# 1   NaN  NaN  NaN  1.0  1.0   4.0  2.0  NaN  1.0  1.0  NaN  NaN  NaN
# 2   NaN  NaN  NaN  1.0  1.0   4.0  2.0  NaN  1.0  1.0  NaN  NaN  NaN
# 3   1.0  NaN  1.0  3.0  4.0   4.0  3.0  NaN  1.0  NaN  NaN  NaN  NaN
# 4   NaN  1.0  NaN  NaN  1.0  10.0  6.0  NaN  NaN  1.0  1.0  NaN  NaN
# 5   NaN  NaN  NaN  NaN  1.0   4.0  4.0  NaN  3.0  NaN  1.0  2.0  NaN
# 6   2.0  NaN  NaN  2.0  1.0   3.0  1.0  1.0  2.0  1.0  NaN  NaN  1.0
# 7   1.0  NaN  1.0  2.0  6.0   6.0  6.0  NaN  4.0  2.0  2.0  NaN  NaN
# 8   5.0  1.0  NaN  NaN  3.0   5.0  3.0  NaN  NaN  NaN  1.0  2.0  1.0
# 9   2.0  NaN  NaN  1.0  1.0   4.0  2.0  NaN  NaN  NaN  1.0  2.0  NaN
# 10  2.0  NaN  NaN  1.0  1.0   4.0  2.0  NaN  1.0  NaN  NaN  1.0  NaN
# 11  2.0  NaN  NaN  1.0  3.0   4.0  2.0  NaN  1.0  NaN  NaN  1.0  NaN
# 12  1.0  NaN  NaN  1.0  1.0   3.0  4.0  NaN  2.0  1.0  1.0  NaN  NaN
# 13  NaN  1.0  NaN  NaN  1.0   2.0  2.0  NaN  1.0  NaN  1.0  NaN  NaN
# 14  2.0  NaN  NaN  NaN  1.0   5.0  4.0  NaN  1.0  1.0  1.0  NaN  NaN
# 15  NaN  1.0  NaN  1.0  1.0   2.0  5.0  NaN  1.0  NaN  NaN  1.0  NaN
# 16  NaN  NaN  NaN  NaN  1.0   5.0  2.0  NaN  2.0  NaN  NaN  1.0  NaN
# 17  NaN  NaN  NaN  NaN  3.0   5.0  2.0  NaN  2.0  NaN  NaN  1.0  NaN
# 18  NaN  NaN  NaN  1.0  1.0   5.0  2.0  NaN  1.0  NaN  NaN  1.0  NaN
# 19  1.0  NaN  NaN  NaN  3.0   5.0  7.0  1.0  2.0  1.0  NaN  NaN  1.0
# 20  2.0  1.0  NaN  1.0  1.0   3.0  2.0  1.0  1.0  NaN  NaN  NaN  NaN
# 21  NaN  NaN  NaN  1.0  1.0   5.0  3.0  1.0  3.0  NaN  NaN  NaN  NaN
# 22  NaN  NaN  NaN  4.0  NaN   1.0  1.0  NaN  1.0  NaN  NaN  2.0  NaN

# %%
def make_df(string_list,col):
    list1 = [[chunk(sent)[i][col] for i in range(len(chunk(sent)))] for sent in no_comma]
    cols = list(set(itertools.chain.from_iterable(list1)))
    df = pd.DataFrame(columns = cols,dtype = "int")
    for item in list1:
        df = df.append(pd.Series(Counter(item),index = cols),ignore_index = True)
#     df[df.isna()] = 0
    return df

# %%
df2 = make_df(no_comma,2)

# %%
df2.notna()
# Out:
#      B-AP   I-NP  B-VP  B-NP      O   B-PP
# 0   False  False  True  True   True  False
# 1   False  False  True  True   True   True
# 2   False  False  True  True   True   True
# 3    True  False  True  True   True   True
# 4   False  False  True  True   True  False
# 5   False  False  True  True   True   True
# 6    True   True  True  True   True   True
# 7    True  False  True  True   True   True
# 8    True  False  True  True   True  False
# 9    True  False  True  True   True  False
# 10   True  False  True  True   True   True
# 11   True  False  True  True   True   True
# 12   True  False  True  True   True   True
# 13  False  False  True  True   True   True
# 14   True  False  True  True   True   True
# 15  False  False  True  True   True   True
# 16  False  False  True  True   True   True
# 17  False  False  True  True   True   True
# 18  False  False  True  True   True   True
# 19   True  False  True  True   True   True
# 20   True  False  True  True   True   True
# 21  False  False  True  True   True   True
# 22  False   True  True  True  False   True

# %%
sns.binomial(data = df2.notna())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-143-25088b7b61d6> in <module>
# ----> 1 sns.binomial(data = df2.notna())
#
# AttributeError: module 'seaborn' has no attribute 'binomial'
